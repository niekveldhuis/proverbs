# %%
with open('aliases.txt') as a:
    alias = a.read().splitlines()

# %%
alias_d = {}

# %%
for line in alias:
    aliases = line.split()
    for value in aliases[1:]:
        alias_d[value] = aliases[0]

# %%
alias_d
# Out:
# {'aba': 'ab',
#  'ap': 'ab',
#  'ap₂': 'ab₂',
#  'abšin₃': 'absin₃',
#  'abulla': 'abul',
#  'abula': 'abul',
#  'absu': 'abzu',
#  'at': 'ad',
#  'ada': 'ad',
#  'at₂': 'ad₂',
#  'at₆': 'ad₆',
#  'adda': 'ad₆',
#  'adamen₂': 'adamin₂',
#  'adamen₄': 'adamin₄',
#  'agar₅': 'aŋar₅',
#  'agar₆': 'aŋar₆',
#  'aŋrig': 'agrig',
#  'agru₊(E₂.NUN)': 'agrun',
#  'agruna₊(E₂.NUN)': 'agrun',
#  'ag₂': 'aŋ₂',
#  'aga₂': 'aŋ₂',
#  'aka₂': 'aŋ₂',
#  'iŋ₃': 'eŋ₃',
#  'eg₃': 'eŋ₃',
#  'ig₃': 'eŋ₃',
#  'aka': 'ak',
#  'ag': 'ak',
#  'a₅': 'ak',
#  'akani': 'akan',
#  'akan₃': 'akkan₃',
#  'ala₃': 'al',
#  'alu': 'ala',
#  'al₈': 'ala',
#  'ale': 'ala',
#  'ali': 'ala',
#  'alan': 'alam',
#  'algames': 'algameš',
#  'algamis': 'algameš',
#  'alima': 'alim',
#  'ama₂': 'am',
#  'amaša': 'amaš',
#  'ambara': 'ambar',
#  'anbar': 'ambar',
#  'abbar': 'ambar',
#  'amuša': 'amuš',
#  'anu': 'an',
#  'ana₂': 'an',
#  'am₆': 'an',
#  'anšu': 'anše',
#  'hanzalub': 'anzalub',
#  'apina': 'apin',
# ...
